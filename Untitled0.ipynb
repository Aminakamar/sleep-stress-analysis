# %%
# !pip install kaggle

# %%
from google.colab import files
files.upload()
# Out:
#      <input type="file" id="files-fe3091f8-9d12-4919-9126-8fb59a6dc01a" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-fe3091f8-9d12-4919-9126-8fb59a6dc01a">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt

# load data
df = pd.read_csv(list(uploaded.keys())[0])

df.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_14767/2197938760.py in <cell line: 0>()
#       3
#       4 # load data
# ----> 5 df = pd.read_csv(list(uploaded.keys())[0])
#       6
#       7 df.head()
#
# NameError: name 'uploaded' is not defined

# %%
df = pd.read_csv(list(uploaded.keys())[0])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_14767/3891359891.py in <cell line: 0>()
# ----> 1 df = pd.read_csv(list(uploaded.keys())[0])
#
# NameError: name 'uploaded' is not defined

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-f166adc1-72af-445e-8a8c-65b1e2f860d1" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-f166adc1-72af-445e-8a8c-65b1e2f860d1">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
df = pd.read_csv(list(uploaded.keys())[0])

# %%
import pandas as pd
import matplotlib.pyplot as plt

# load data
df = pd.read_csv(list(uploaded.keys())[0])

df.head()
# Out:
#    user_id  age  gender         occupation  daily_screen_time_hours  \
# 0        1   56  Female           Designer                     3.26
# 1        2   46  Female            Teacher                     1.85
# 2        3   32  Female           Designer                     3.04
# 3        4   25    Male  Software Engineer                     9.00
# 4        5   38  Female            Teacher                     3.52
#
#    phone_usage_before_sleep_minutes  sleep_duration_hours  \
# 0                                86                  5.31
# 1                                32                  7.36
# 2                               107                  4.50
# 3                                36                  6.68
# 4                                56                  7.57
#
#    sleep_quality_score  stress_level  caffeine_intake_cups  \
# 0                 7.72          3.49                     0
# 1                 9.70          3.01                     0
# ...

# %%
df = df.dropna()

# %%
plt.scatter(df['Screen Time'], df['Sleep Duration'])
plt.xlabel("Screen Time")
plt.ylabel("Sleep Duration")
plt.title("Screen Time vs Sleep")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.12/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3804         try:
# -> 3805             return self._engine.get_loc(casted_key)
#    3806         except KeyError as err:
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Screen Time'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# /tmp/ipykernel_14767/4217750640.py in <cell line: 0>()
# ----> 1 plt.scatter(df['Screen Time'], df['Sleep Duration'])
# ...

# %%
print(df.columns)
# Out:
# Index(['user_id', 'age', 'gender', 'occupation', 'daily_screen_time_hours',
#        'phone_usage_before_sleep_minutes', 'sleep_duration_hours',
#        'sleep_quality_score', 'stress_level', 'caffeine_intake_cups',
#        'physical_activity_minutes', 'notifications_received_per_day',
#        'mental_fatigue_score'],
#       dtype='object')

# %%
import matplotlib.pyplot as plt

plt.scatter(df['Sleep Duration'], df['Stress Level'])
plt.xlabel("Sleep Duration")
plt.ylabel("Stress Level")
plt.title("Sleep vs Stress")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.12/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3804         try:
# -> 3805             return self._engine.get_loc(casted_key)
#    3806         except KeyError as err:
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Sleep Duration'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# /tmp/ipykernel_14767/21065511.py in <cell line: 0>()
#       1 import matplotlib.pyplot as plt
#       2
# ...

# %%
print(df.columns)
# Out:
# Index(['user_id', 'age', 'gender', 'occupation', 'daily_screen_time_hours',
#        'phone_usage_before_sleep_minutes', 'sleep_duration_hours',
#        'sleep_quality_score', 'stress_level', 'caffeine_intake_cups',
#        'physical_activity_minutes', 'notifications_received_per_day',
#        'mental_fatigue_score'],
#       dtype='object')

# %%
import matplotlib.pyplot as plt

plt.scatter(df['daily_screen_time_hours'], df['sleep_duration_hours'])
plt.xlabel("Screen Time (hours)")
plt.ylabel("Sleep Duration (hours)")
plt.title("Screen Time vs Sleep")
plt.show()

# %%
plt.scatter(df['daily_screen_time_hours'], df['stress_level'])
plt.xlabel("Screen Time (hours)")
plt.ylabel("Stress Level")
plt.title("Screen Time vs Stress")
plt.show()

# %%
plt.scatter(df['sleep_duration_hours'], df['stress_level'])
plt.xlabel("Sleep Duration")
plt.ylabel("Stress Level")
plt.title("Sleep vs Stress")
plt.show()

# %%
print("Average Screen Time:", df['daily_screen_time_hours'].mean())
print("Average Sleep:", df['sleep_duration_hours'].mean())
print("Average Stress:", df['stress_level'].mean())
# Out:
# Average Screen Time: 5.5015279999999995
# Average Sleep: 6.509683333333333
# Average Stress: 6.980246666666666

# %%
corr = df[['daily_screen_time_hours',
           'sleep_duration_hours',
           'stress_level']].corr()

print(corr)
# Out:
#                          daily_screen_time_hours  sleep_duration_hours  \
# daily_screen_time_hours                 1.000000             -0.001838
# sleep_duration_hours                   -0.001838              1.000000
# stress_level                            0.879001             -0.004893
#
#                          stress_level
# daily_screen_time_hours      0.879001
# sleep_duration_hours        -0.004893
# stress_level                 1.000000

# %%
import matplotlib.pyplot as plt

plt.imshow(corr)
plt.colorbar()
plt.xticks(range(len(corr.columns)), corr.columns, rotation=45)
plt.yticks(range(len(corr.columns)), corr.columns)
plt.title("Correlation Heatmap")
plt.show()

# %% [markdown]
# Result:
#
# The average screen time is moderately high (~5.5 hours/day).
# Average sleep duration is slightly low (~6.5 hours).
# Stress levels are relatively high (~7).

# %% [markdown]
# Conclusion:
#
# Increased screen time is associated with reduced sleep duration.
# Reduced sleep leads to higher stress levels.
# Therefore, managing screen time can improve sleep and reduce stress.
